# %% [markdown]
# <div align="center">
# <p><img alt="UdeA" height="150px" src="https://minas.medellin.unal.edu.co/proyectos/one-health-consortium/images/unal.png" align="center" hspace="10px" vspace="0px"></p>
# </div>
# <div> </div>
#
#
# <p>
# <h6 align="center"> <b> </b> </h6>
# <h1 align="center"> <b> Taller Fundamentos de Programación </b> </h1>
# <h2 align="center"> <b> Listas (Compuestas) y Diccionarios </b> </h2>
# <hr size=10 noshade color="gray">
# </p>
# <p>
# <img alt="CC" height="70px" src="https://creativecommons.org/images/deed/cc_blue_x2.png" align="left" hspace="0px" vspace="0px">
# <img alt="Attribution" height="70px" src="https://creativecommons.org/images/deed/attribution_icon_blue_x2.png" align="left" hspace="0px" vspace="0px">
# <img alt="NC" height="70px" src="https://creativecommons.org/images/deed/nc_blue_x2.png" align="left" hspace="0px" vspace="0px">
# <img alt="SA" height="70px" src="https://creativecommons.org/images/deed/sa_blue_x2.png" align="left" hspace="0px" vspace="0px">
# <br></br><br></br>
# </p>
#
# <hr size=1 noshade color="black">
# <div align="right">
# <h1> <strong>Docente: Laura Lotero </strong></h1>
# <h2><a href="mailto:llotero0@unal.edu.co">✉ Laura Lotero</a></h2>
#
# <hr size=1 noshade color="black">
#
# <h2> <strong>BEDA: Julián Castillo </strong></h2>
# <h3><a href="mailto:jacastil@unal.edu.co">✉ Julian Castillo</a></h3>
# <hr size=1 noshade color="black">
#
# <hr size=10 noshade color="purple">
# </div>
#
#
# <div align="center">
#
# <h3><a href="https://minaslap.net/course/view.php?id=320">Enlace MinasLAP</a></h3>
#
# [![MinasLAP](https://minaslap.net/pluginfile.php/1/core_admin/logocompact/300x300/1755051362/Logo%20MinasLAP-3%20%281%29.png)](https://minaslap.net/course/view.php?id=320)

# %% [markdown]
# # **QR de Acceso**
#
# <table border="1">
#     <thead>
#     <tr>
#         <th>Google Colab</th>
#         <th>GitHub</th>
#     </tr>
#     </thead>
#     <tbody>
#     <tr>
#         <td>
#         <img
#             src="https://raw.githubusercontent.com/JulianCastillo-Unal/FundamentosProgramacion/refs/heads/main/QR_CursoFundamentosTallerCondicionales.png"
#             alt="QR Curso Fundamentos Taller Condicionales - Google Colab">
#         </td>
#         <td>
#         <img
#             src="https://raw.githubusercontent.com/JulianCastillo-Unal/FundamentosProgramacion/refs/heads/main/QR_CursoFundamentosTallerCondicionales_GitHub.png"
#             alt="QR Curso Fundamentos Taller Condicionales - GitHub">
#         </td>
#     </tr>
#     </tbody>
# </table>

# %% [markdown]
# # **Taller de Listas y Funciones**
#
# El presente taller contiene un resumen de las estructuras listas y funciones en conjunto con ejemplos de cada una de ellas y los ejercicios propuestos para solucionar en clase.

# %% [markdown]
# # **Listas**
#
# La información de las listas se encuentra disponible en el taller anterior.

# %% [markdown]
# # **Diccionarios**

# %% [markdown]
# ## **Dict (Diccionarios)**
#
# Los diccionarios se utilizan para almacenar valores de datos en pares *clave: valor*.
#
# Un diccionario es una colección ordenada, modificable y que no admite duplicados. Los diccionarios se escriben con llaves y tienen claves y valores.
#
# >Crear un Diccionario
# ```python
# undiccionario = {
#   "Arroz": "Cereal",
#   "Papa": "Tuberculo",
#   "CantArroz": 1000,
#   "CantPapa": 2000
# }
# print(undiccionario)
# ```

# %%
# !python --version

# %%
undiccionario = {
  "Arroz": "Cereal",
  "Papa": "Tuberculo",
  "CantArroz": 1000,
  "CantPapa": 2000
}
print(undiccionario)

# %% [markdown]
# ### **Ítems de un Diccionario**
# <p>
#
# Los elementos del diccionario están ordenados, se pueden cambiar y no permiten duplicados. Los elementos del diccionario se presentan en pares clave: valor y se puede hacer referencia a ellos mediante el nombre de la clave.
#
# </p>

# %%
undiccionario = {
  "Arroz": "Cereal",
  "Papa": "Tuberculo",
  "CantArroz": 1000,
  "CantPapa": 2000
}
print(undiccionario["Arroz"])
print(undiccionario["CantArroz"])

# %% [markdown]
# ### **Ítems de un Diccionario**
# <p>
#
# **¿Ordenado o desordenado?**
# A partir de la versión 3.7 de Python, los diccionarios están ordenados. En Python 3.6 y versiones anteriores, los diccionarios están desordenados. Cuando decimos que los diccionarios están ordenados, significa que los elementos tienen un orden definido y ese orden no cambiará. Desordenado significa que los artículos no tienen un orden definido, no puede hacer referencia a un artículo usando un índice.
#
# **Cambiable o mutable**
# Los diccionarios se pueden cambiar o mutar o modificar, lo que significa que podemos cambiar, agregar o eliminar elementos después de que se haya creado el diccionario.
#
# **No se permiten duplicados**
# Los diccionarios no pueden tener dos elementos con la misma clave, en caso de duplicar una clave conserva la última ingresada.
#
# </p>

# %%
undiccionario = {
  "Arroz": "Cereal",
  "Papa": "Tuberculo",
  "CantArroz": 1000,
  "CantArroz": 1500,
  "CantArroz": 2000,
  "CantPapa": 2000
}
print(undiccionario)

# %% [markdown]
# ### **Diccionarios y funciones**
# <p>
#
# **Longitud del diccionario**
# Para determinar cuántos elementos tiene un diccionario, se usa la función `len()`:
#
# ```python
# print(len(undiccionario))
# ```
#
# **Ítem y tipos de datos del diccionario**
# Los valores de los elementos del diccionario pueden ser de cualquier tipo de datos:
#
# ```python
# undiccionario = {
#   "Arroz": "Cereal",
#   "Papa": "Tuberculo",
#   "CantArroz": 1000,
#   "CantArroz": 1500,
#   "CantArroz": 2000,
#   "CantPapa": 2000,
#   "Vendedores": ["Dario Gomez", "Michael Jackson", "Metallica"]
# }
# print(undiccionario)
# ```
# **Data Type del diccionario**
# Desde la perspectiva de Python, los diccionarios se definen como objetos con el tipo de datos 'dict':
#
# ```python
# print(type(undiccionario))
# ```
# </p>

# %%
undiccionario = {
  "Arroz": "Cereal",
  "Papa": "Tuberculo",
  "CantArroz": 1000,
  "CantArroz": 1500,
  "CantArroz": 2000,
  "CantPapa": 2000,
  "Vendedores": ["Dario Gomez", "Michael Jackson", "Metallica"]
}
print(len(undiccionario))
print(undiccionario)
print(type(undiccionario))

# %% [markdown]
# ### **Acceder a los datos de un Diccionario**
# <p>
#
# **Acceder a elementos**
#
# Puede acceder a los elementos de un diccionario haciendo referencia a su clave, entre corchetes, este contexto retorna el valor, el método `get()` tiene los mismos resultados:
#
# ```python
# undiccionario = {
#   "Arroz": "Cereal",
#   "Papa": "Tuberculo",
#   "CantArroz": 1000,
#   "CantArroz": 1500,
#   "CantArroz": 2000,
#   "CantPapa": 2000,
#   "Vendedores": ["Dario Gomez", "Michael Jackson", "Metallica"]
# }
# x = undiccionario["Arroz"]
# print(x)
# y = undiccionario.get("Papa")
# print(y)
# ```
#
#
# </p>

# %%
undiccionario = {
  "Arroz": "Cereal",
  "Papa": "Tuberculo",
  "CantArroz": 1000,
  "CantArroz": 1500,
  "CantArroz": 2000,
  "CantPapa": 2000,
  "Vendedores": ["Dario Gomez", "Michael Jackson", "Metallica"]
}

x = undiccionario["Arroz"]
print(x)
y = undiccionario.get("Papa")
print(y)

# %% [markdown]
# ### **Acceder a las llaves o claves de un Diccionario**
# <p>
#
# **Acceder o modificar claves y valores de un Diccionario**
#
# El método `keys()` devolverá una lista de todas las claves del diccionario.
# La lista de claves es una vista del diccionario, lo que significa que cualquier cambio realizado en el diccionario se reflejará en la lista de claves.
#
# ```python
# empanadas = {"masa": "maiz","nombre": "empanada","cantidad": 100}
# x = empanadas.keys()
# print(x)  #Agregamos una nueva clave
# empanadas["color"] = "amarillito"
# print(x)
# ```
#
# ---
#
# **Acceder a los valores**
#
# El método `values()` devolverá una lista de todos los valores en el diccionario.
# La lista de valores es una vista del diccionario, lo que significa que cualquier cambio realizado en el diccionario se reflejará en la lista de valores.
# ```python
# empanadas = {"masa": "maiz","nombre": "empanada","cantidad": 100}
# y = empanadas.values()
# print(y)  #Agregamos una nueva clave
# empanadas["color"] = "amarillito"
# print(y)
# ```
#
# ---
#
# **Acceder a los ítems**
#
# El método `items()` devolverá cada elemento en un diccionario, como tuplas en una lista. La lista devuelta es una vista de los elementos del diccionario, lo que significa que cualquier cambio realizado en el diccionario se reflejará en la lista de elementos.
# ```python
# empanadas = {"masa": "maiz","nombre": "empanada","cantidad": 100, "color":"amarillito"}
# z = empanadas.items()
# print(z)  #Actualizamos el color y se refleja en la vista
# empanadas["color"] = "amarillo"
# print(z)
# ```
# ---
#
# **Verificar si una clave existe**
#
# Para determinar si una clave existe en un diccionario, utilizamos el operadore de membresía `in`.
# ```python
# empanadas = {"masa": "maiz","nombre": "empanada","cantidad": 100, "color":"amarillito"}
# z = empanadas.items()
# print("masa" in empanadas)
# print("arroz" in empanadas)
# ```
# ---
#
# **Cambiar valores**
#
# Se puede cambiar el valor de un ítem especifico haciendo uso de la clave.
# ```python
# empanadas = {"masa": "maiz","nombre": "empanada","cantidad": 100, "color":"amarillito"}
# empanadas["cantidad"] = 200
# print(empanadas)
# ```
# ---
#
# **Actualizar el Diccionario**
#
# El método `update()` actualizará el diccionario con los elementos del argumento dado. El argumento debe ser un diccionario o un objeto iterable con pares clave: valor. Este método permite ingresar nuevos valores de clave y valor.
# ```python
# empanadas = {"masa": "maiz","nombre": "empanada","cantidad": 100, "color":"amarillito"}
# empanadas.update({"cantidad":300})
# empanadas.update({"comprador":"Lionel Messi"})
# print(empanadas)
# ```
# </p>

# %%
empanadas = {
"masa": "maiz",
"nombre": "empanada",
"cantidad": 100
}
x = empanadas.keys()
print(x)
empanadas["color"] = "amarillito"
print(x)
y = empanadas.values()
print(y)
z = empanadas.items()
print(z)  #Actualizamos el color y se refleja en la vista
empanadas["color"] = "amarillo"
print(z)
print("masa" in empanadas)
print("arroz" in empanadas)
empanadas["cantidad"] = 200
print(empanadas)
empanadas.update({"cantidad":300})
print(empanadas)
empanadas.update({"comprador":"Lionel Messi"})
print(empanadas)

# %% [markdown]
# ### **Eliminar llaves o claves de un Diccionario**
# <p>
#
# **Eliminar elementos**
#
# Existen varios métodos para eliminar elementos de un diccionario:
# El método `pop()` elimina el elemento con el nombre de clave especificado:
#
# ```python
# empanadas = {"masa": "maiz","nombre": "empanada","cantidad": 100, "color":"amarillito", "comprador":"Liones Messi"}
# print(empanadas)
# empanadas.pop("comprador")
# print(empanadas)
# ```
# ---
# **Eliminar ítems**
#
# El método `popitem()` elimina el último elemento insertado (en las versiones anteriores a la 3.7, se elimina un elemento aleatorio):
#
# ```python
# empanadas = {"masa": "maiz","nombre": "empanada","cantidad": 100, "color":"amarillito", "comprador":"Liones Messi"}
# print(empanadas)
# empanadas.popitem()
# print(empanadas)
# ```
# ---
# **Eliminar Diccionarios**
#
# La palabra clave `del` elimina completamente
# **Nota: Acceder a un objeto eliminado usando la instrucción `del` genera un error debido a que el objeto no existe.**
#
# ```python
# empanadas = {"masa": "maiz","nombre": "empanada","cantidad": 100, "color":"amarillito", "comprador":"Liones Messi"}
#
# del empanadas
# ```
# ---
# **Limpiar Diccionarios**
#
# Usando el método `clear()` se eliminan todos los objetos del diccionario.
#
# ```python
# empanadas = {"masa": "maiz","nombre": "empanada","cantidad": 100, "color":"amarillito", "comprador":"Liones Messi"}
# empanadas.clear()
# print(empanadas)
# ```
# ---
#
# </p>

# %%
empanadas = {"masa": "maiz","nombre": "empanada","cantidad": 100, "color":"amarillito", "comprador":"Liones Messi"}
print(empanadas)
empanadas.pop("comprador")
print(empanadas)
empanadas.popitem()
print(empanadas)
empanadas.clear()
print(empanadas)

# %% [markdown]
# ### **Métodos de los Diccionarios**
# <p>
#
# Python tiene un conjunto de métodos integrados que puede usar en diccionarios.
#
# Metodo | Descripción
# --- | ---
# `clear(`) | Elimina todos los elementos del diccionario
# `copy(`) | Devuelve una copia del diccionario
# `fromkeys(`) | Devuelve un diccionario con las claves y el valor especificados
# `get(`) | Devuelve el valor de la clave especificada
# `items(`) | Devuelve una lista que contiene una tupla para cada par clave-valor
# `keys(`) | Devuelve una lista que contiene las claves del diccionario
# `pop(`) | Elimina el elemento con la clave especificada
# `popitem(`) | Elimina el último par clave-valor insertado
# `setdefault(`) | Devuelve el valor de la clave especificada. Si la clave no existe: inserte la clave, con el valor especificado
# `update(`) | Actualiza el diccionario con los pares clave-valor especificados
# `values(`) | Devuelve una lista de todos los valores en el diccionario.
#
# </p>

# %% [markdown]
# # **Taller de Ejercicios Propuestos**
#
# ## ***Jueves 13 de noviembre***

# %% [markdown]
# ### **`Ejercicio A` `Listas`**
#
# En la gestión de reservas de asientos en salas de cine, uno de los principales desafíos es mantener un control claro y actualizado de la disponibilidad de los asientos, evitando conflictos por doble asignación o errores en el registro manual. En muchos casos, este proceso se realiza mediante listados impresos o sistemas poco automatizados, lo que incrementa la probabilidad de confusiones, especialmente cuando la cantidad de asientos o espectadores es alta.
#
# El problema radica en la necesidad de contar con un sistema computacional sencillo, interactivo y eficiente que permita visualizar de forma clara la disposición de los asientos de una sala de cine, registrar las reservas realizadas y actualizar en tiempo real el estado de cada asiento. Este sistema debe ofrecer una interfaz intuitiva que permita al usuario consultar la disponibilidad, seleccionar su asiento y confirmar la reserva de manera rápida, minimizando los errores humanos y optimizando el proceso de atención al cliente.
#
# El código propuesto aborda esta problemática mediante la implementación de un sistema de reserva de asientos en consola. A través de una representación matricial (11x11) de la sala de cine, cada asiento se identifica con un símbolo que indica su estado: 'O' para disponible y 'X' para ocupado. El programa incorpora un menú interactivo que permite visualizar la sala, reservar asientos y salir del sistema.
#
# Este sistema constituye una solución funcional al problema de la gestión manual de reservas, proporcionando una base que puede extenderse hacia aplicaciones con interfaz gráfica o conexión a bases de datos, mejorando la experiencia tanto del operador como del usuario final.
#
# Recuerda usar las funciones detalladas en la celda contigua y realiza una propuesta de solución.
#
#
# Nivel de dificultad:★★★★☆
#
#
# ![image.png](data:image/png;base64,...)

# %%
def CrearCinema():
    """
    Crea una matriz 11x11 representando los asientos de un cine.
    Cada asiento se inicializa con '0' (disponible).
    Returns:
        list: Una lista de listas que representa la sala de cine con todos los asientos disponibles.
    """
    # Usando List Comprehension (Tecnica medio avanzada pero muy chevere)
    # lstAsientosCine = [['O' for i in range(11)] for j in range(11)]
    lstAsientosCine = []
    for i in range(11):
        fila = []
        for j in range(11):
            fila.append('O')
        lstAsientosCine.append(fila)
    return lstAsientosCine

def ImprimirSalaCinema(lstAsientos:list):
    """
    Imprime en la consola la representación gráfica de la sala de cine.
    Muestra un encabezado, las letras de las filas y el estado de cada asiento.

    Args:
        lstAsientos (list): Una lista de listas que representa la sala de cine,
                            donde 'O' es un asiento disponible y 'X' es un asiento ocupado.
    Returns:
        None: Imprime el cinema usando print()'s
    """
    lstLetras11 = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K']
    print('='*60)
    print('CINEMA Interstellar (O Disponible) (X Ocupado)'.center(60))
    print('='*60)
    print(' '*4, end="")
    for c in lstLetras11:print(c, end='    ')
    print()
    for i, j in enumerate(lstAsientos):
        print(lstLetras11[i], end=' ')
        print(j)
    print('='*60)

def ImprimirMenu():
    menu = """
        ...:::Cinema Interstellar:::...
        1. Ver disponibilidad
        2. Reservar Sillas
        3. Salir
    """

# %%
#Solución

# %% [markdown]
# ### **`Ejercicio B` `Diccionarios`**
#
#
# En los entornos comerciales de pequeña escala, como tiendas de barrio o minimercados, es frecuente la necesidad de registrar las ventas diarias de manera organizada y eficiente. Sin embargo, muchas de estas operaciones se realizan de forma manual, lo que puede generar errores en el registro de productos, pérdidas de información o dificultades al momento de calcular los totales de venta. Surge entonces la necesidad de contar con una herramienta sencilla que permita automatizar el proceso de registro de ventas, sin requerir sistemas complejos ni conocimientos avanzados en informática.
#
# El presente programa responde a esta necesidad mediante el desarrollo de un sistema básico de ventas ejecutado en consola. Este sistema permite al usuario registrar las ventas realizadas a cada cliente, identificándolos a través de su número de documento e ingresando los productos adquiridos junto con su valor correspondiente.
#
# El código implementa dos estructuras principales:
#
# Un diccionario denominado dicProductos, que actúa como una base de datos interna donde se almacenan los productos disponibles y sus precios el cual se presenta a continuación:
#
# ```python
# # Base de datos
# dicProductos = {"arroz": 4200, "huevos": 13500,
# 				"leche": 4200, "aceite": 9800,
# 				"azucar": 3700, "cafe": 11500,
# 				"detergente": 8200, "suavizante": 9000,
# 				"jabon": 2500, "papel": 5500,
# 				"shampoo": 14500, "cremadental": 5200,
# 				"toallas": 3500, "esponja": 1800,
# 				"lavaloza": 4200, "arepas": 6500,
# 				"pan": 5800, "gaseosa": 5200,
# 				"atun": 6500, "frijol": 4500,
# 				"lentejas": 4200, "pasta": 3900,
# 				"sal": 1500, "mantequilla": 6800,
# 				"queso": 9800, "jamon": 9200,
# 				"cereal": 10500, "galletas": 3600,
# 				"agua": 2500, "limpavidrios": 7800,
# 				"desinfectante": 6900, "trapero": 8500,
# 				"escoba": 7200, "bolsasbasura": 4800,
# 				"velas": 2000, "foco": 6500,
# 				"cemento": 32000, "pintura": 28000
# 				}
# ```
#
# Un diccionario dicVentas, que cumple la función de registro persistente de las compras realizadas por cada cliente durante la sesión.
#
# El flujo del programa se organiza a través de un menú interactivo, el cual ofrece opciones para iniciar una venta, visualizar productos y totales, o finalizar la ejecución. Cuando el usuario selecciona la opción de iniciar una venta, el sistema solicita el número de documento del cliente y permite registrar múltiples productos, validando que estos existan en el inventario antes de ser añadidos. Al ingresar un valor numérico, el proceso de registro finaliza y el sistema retorna al menú principal.
#
# De esta manera, el programa soluciona el problema de registro manual de ventas, automatizando tareas repetitivas y reduciendo la posibilidad de errores humanos. Además, su diseño modular y el uso de estructuras de datos flexibles facilitan la futura incorporación de nuevas funcionalidades, como la impresión de facturas, el cálculo automático de totales o la integración con bases de datos externas.
#
# Recuerda usar diccionarios y realiza una propuesta de solución.
#
# Nivel de dificultad:★★★★☆

# %%
#Solución
